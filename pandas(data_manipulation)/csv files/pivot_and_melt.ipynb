# %% [markdown]
# pivot and melt  - used to reshape the file

# %%
 import numpy as np 
 import pandas as pd

# %%
data=pd.read_csv("sample_sales_dataset_25_rows.csv")

# %%
data
# Out:
#           Date Product Region  Sales  Units    Rep    Month Quarter
# 0   2023-01-01       C   West    564     59    Bob  January      Q1
# 1   2023-01-02       A   East    959     45  Alice  January      Q1
# 2   2023-01-03       A   East    871     89  David  January      Q1
# 3   2023-01-04       B   East    590      9   John  January      Q1
# 4   2023-01-05       D  North    811     23    Bob  January      Q1
# 5   2023-01-06       C   East    151     44   John  January      Q1
# 6   2023-01-07       D   West    829     32   John  January      Q1
# 7   2023-01-08       D  North    494     56  Alice  January      Q1
# 8   2023-01-09       C   East    785     51    Bob  January      Q1
# 9   2023-01-10       C  South    758     28    Bob  January      Q1
# 10  2023-01-11       A  North    502     97    Bob  January      Q1
# 11  2023-01-12       D   West    857     85   John  January      Q1
# 12  2023-01-13       D   West    906     76   John  January      Q1
# ...

# %%
pd.pivot_table(data,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     915.0  383.5  468.0  696.5
# North    502.0  593.0  741.5  652.5
# South      NaN  487.0  842.5  342.5
# West       NaN    NaN  564.0  843.0

# %%
pivot2=pd.pivot_table(data,values=['Sales','Units'],index='Region',columns='Product')

# %%
pivot2
# Out:
#          Sales                       Units
# Product      A      B      C       D     A     B     C     D
# Region
# East     915.0  383.5  468.0  696.50  67.0  49.0  47.5  90.0
# North    502.0  593.0  741.5  652.50  97.0  52.0  91.5  39.5
# South      NaN  487.0  842.5  342.50   NaN  32.0  63.0  55.5
# West       NaN    NaN  564.0  761.75   NaN   NaN  59.0  58.0

# %% [markdown]
# crosstabs-used counting function

# %%
pd.crosstab(data['Region'],data['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     2  2  2  2
# North    1  1  2  2
# South    0  2  2  2
# West     0  0  1  4
