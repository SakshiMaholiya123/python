# %% [markdown]
# dropna and fillna

# %%
import pandas as pd
csv_file=pd.read_csv("C:\\Users\\DELL\\Downloads\\employees.csv")

# %%
csv_file
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi      NaN  Marketing         1.0
# 8    9      Vikas  28.0    Male        NaN  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0        NaN         2.0
# 10  11      Rohit  30.0    Male  Bangalore  72000.0    Finance         NaN
# ...

# %%
csv_file.dropna()
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 12  13     Aditya  27.0    Male      Delhi  61000.0         IT         4.0
# 13  14      Kavya  25.0  Female  Hyderabad  53000.0  Marketing         3.0
# 14  15     Manish  29.0    Male    Chennai  71000.0    Finance         6.0
# 17  18     Ritika  24.0  Female      Delhi  48000.0  Marketing         2.0
# ...

# %%
csv_file.dropna(axis=1)
# Out:
#     id       name  gender
# 0    1       Siya  Female
# 1    2       Aman    Male
# 2    3      Rahul    Male
# 3    4      Priya  Female
# 4    5      Karan    Male
# 5    6       Neha  Female
# 6    7      Arjun    Male
# 7    8      Meera  Female
# 8    9      Vikas    Male
# 9   10     Anjali  Female
# 10  11      Rohit    Male
# 11  12      Sneha  Female
# 12  13     Aditya    Male
# 13  14      Kavya  Female
# 14  15     Manish    Male
# 15  16      Pooja  Female
# 16  17      Ayush    Male
# 17  18     Ritika  Female
# 18  19     Sachin    Male
# 19  20      Divya  Female
# 20  21     Nikhil    Male
# 21  22     Simran  Female
# 22  23      Harsh    Male
# 23  24      Tanya  Female
# 24  25   Abhishek    Male
# 25  26      Komal  Female
# 26  27       Yash    Male
# 27  28       Isha  Female
# 28  29      Rajat    Male
# 29  30     Muskan  Female
# 30  31     Deepak    Male
# 31  32      Naina  Female
# 32  33      Varun    Male
# 33  34     Shreya  Female
# ...

# %%
csv_file.dropna(axis=0)
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 12  13     Aditya  27.0    Male      Delhi  61000.0         IT         4.0
# 13  14      Kavya  25.0  Female  Hyderabad  53000.0  Marketing         3.0
# 14  15     Manish  29.0    Male    Chennai  71000.0    Finance         6.0
# 17  18     Ritika  24.0  Female      Delhi  48000.0  Marketing         2.0
# ...

# %%
csv_file.dropna(how='any')
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 12  13     Aditya  27.0    Male      Delhi  61000.0         IT         4.0
# 13  14      Kavya  25.0  Female  Hyderabad  53000.0  Marketing         3.0
# 14  15     Manish  29.0    Male    Chennai  71000.0    Finance         6.0
# 17  18     Ritika  24.0  Female      Delhi  48000.0  Marketing         2.0
# ...

# %%
csv_file.dropna(how='all')
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi      NaN  Marketing         1.0
# 8    9      Vikas  28.0    Male        NaN  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0        NaN         2.0
# 10  11      Rohit  30.0    Male  Bangalore  72000.0    Finance         NaN
# ...

# %%
#to remove nan value alog a praticular column
csv_file.dropna(subset=['experience'])
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi      NaN  Marketing         1.0
# 8    9      Vikas  28.0    Male        NaN  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0        NaN         2.0
# 11  12      Sneha   NaN  Female     Mumbai  49000.0         HR         3.0
# ...

# %%
#inplace remove all nan value and crete a new dataset
csv_file.dropna(inplace=True)

# %%
csv_file
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 12  13     Aditya  27.0    Male      Delhi  61000.0         IT         4.0
# 13  14      Kavya  25.0  Female  Hyderabad  53000.0  Marketing         3.0
# 14  15     Manish  29.0    Male    Chennai  71000.0    Finance         6.0
# 17  18     Ritika  24.0  Female      Delhi  48000.0  Marketing         2.0
# ...

# %%
csv_file
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 12  13     Aditya  27.0    Male      Delhi  61000.0         IT         4.0
# 13  14      Kavya  25.0  Female  Hyderabad  53000.0  Marketing         3.0
# 14  15     Manish  29.0    Male    Chennai  71000.0    Finance         6.0
# 17  18     Ritika  24.0  Female      Delhi  48000.0  Marketing         2.0
# ...

# %%
csv_file.dropna(thresh=1) #remove the rows with the single nan value

# %%
csv_file=pd.read_csv("C:\\Users\\DELL\\Downloads\\employees.csv")

# %%
csv_file
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi      NaN  Marketing         1.0
# 8    9      Vikas  28.0    Male        NaN  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0        NaN         2.0
# 10  11      Rohit  30.0    Male  Bangalore  72000.0    Finance         NaN
# ...

# %%
csv_file.fillna('python')
# Out:
#     id       name     age  gender       city   salary department experience
# 0    1       Siya    23.0  Female      Delhi  45000.0         HR        2.0
# 1    2       Aman    25.0    Male     Mumbai  52000.0         IT        3.0
# 2    3      Rahul    27.0    Male       Pune  60000.0    Finance        5.0
# 3    4      Priya    24.0  Female  Bangalore  48000.0  Marketing        2.0
# 4    5      Karan    29.0    Male  Hyderabad  75000.0         IT        6.0
# 5    6       Neha    26.0  Female    Chennai  54000.0         HR        4.0
# 6    7      Arjun    31.0    Male    Kolkata  82000.0    Finance        8.0
# 7    8      Meera    22.0  Female      Delhi   python  Marketing        1.0
# 8    9      Vikas    28.0    Male     python  67000.0         IT        5.0
# 9   10     Anjali    24.0  Female       Pune  50000.0     python        2.0
# 10  11      Rohit    30.0    Male  Bangalore  72000.0    Finance     python
# ...

# %%
csv_file.fillna({'age':21,'salary':30000}) #fill the nan value of the particular column
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi  30000.0  Marketing         1.0
# 8    9      Vikas  28.0    Male        NaN  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0        NaN         2.0
# 10  11      Rohit  30.0    Male  Bangalore  72000.0    Finance         NaN
# ...

# %%
#fill the nan value with previous or forward value
csv_file.ffill()
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi  82000.0  Marketing         1.0
# 8    9      Vikas  28.0    Male      Delhi  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0         IT         2.0
# 10  11      Rohit  30.0    Male  Bangalore  72000.0    Finance         2.0
# ...

# %%
csv_file.bfill()
# Out:
#     id       name   age  gender       city   salary department  experience
# 0    1       Siya  23.0  Female      Delhi  45000.0         HR         2.0
# 1    2       Aman  25.0    Male     Mumbai  52000.0         IT         3.0
# 2    3      Rahul  27.0    Male       Pune  60000.0    Finance         5.0
# 3    4      Priya  24.0  Female  Bangalore  48000.0  Marketing         2.0
# 4    5      Karan  29.0    Male  Hyderabad  75000.0         IT         6.0
# 5    6       Neha  26.0  Female    Chennai  54000.0         HR         4.0
# 6    7      Arjun  31.0    Male    Kolkata  82000.0    Finance         8.0
# 7    8      Meera  22.0  Female      Delhi  67000.0  Marketing         1.0
# 8    9      Vikas  28.0    Male       Pune  67000.0         IT         5.0
# 9   10     Anjali  24.0  Female       Pune  50000.0    Finance         2.0
# 10  11      Rohit  30.0    Male  Bangalore  72000.0    Finance         3.0
# ...
